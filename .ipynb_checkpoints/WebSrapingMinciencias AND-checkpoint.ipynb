# %%
#Web Scraping y filtro para Minciencias y separacion de productos

# %%
#pip install openpyxl

# %%
from bs4 import BeautifulSoup
import pandas as pd
from scrapy.selector import Selector
import requests
from bs4 import BeautifulSoup
import warnings

# %%
warnings.filterwarnings('ignore')
warnings.warn('InsecureRequestWarning')
warnings.warn('Do not show this message')

# %%
dfgrupos = pd.read_excel("BDRamca.xlsx", engine='openpyxl') #, sheet_name='Sheet1'
tamaño_dfgrupos =dfgrupos.shape
url= dfgrupos["LINKS"]
dfcon = pd.DataFrame()

# %%
url
# Out:
# 0     https://scienti.minciencias.gov.co/gruplac/jsp...
# 1     https://scienti.minciencias.gov.co/gruplac/jsp...
# 2     https://scienti.minciencias.gov.co/gruplac/jsp...
# 3     https://scienti.minciencias.gov.co/gruplac/jsp...
# 4     https://scienti.minciencias.gov.co/gruplac/jsp...
#                             ...
# 77    https://scienti.minciencias.gov.co/gruplac/jsp...
# 78    https://scienti.minciencias.gov.co/gruplac/jsp...
# 79    https://scienti.minciencias.gov.co/gruplac/jsp...
# 80    https://scienti.minciencias.gov.co/gruplac/jsp...
# 81    https://scienti.minciencias.gov.co/gruplac/jsp...
# Name: LINKS, Length: 82, dtype: object

# %%
#Para el ejemplo 
#url = url[0:5]

# %%
#lo use porque se corto en el link 8 

dfcon = pd.read_excel("InormacionFiltrada.xlsx",engine='openpyxl') #sheet_name='Sheet1', 
dfcon
# Out:
#     Index                                   Nombre del Grupo  \
# 0       0  CENTRO DE INVESTIGACIONES EN INGENIERIA AMBIENTAL
# 1       1          Diagnóstico y Control de la Contaminación
# 2       2  Grupo de Investigación en Gestión y Modelación...
# 3       3                        INVEMAR - Ecología Pesquera
# 4       4  Posgrado en Aprovechamiento de Recursos Hidráu...
# ..    ...                                                ...
# 70     75  Grupo de Estudio en Geología, Ecología y Conse...
# 71     76  GICMIL Grupo de Investigación en Comunicacione...
# 72     77  INVESTIGACION UNIVERSITARIA EN TECNOLOGIAS DE ...
# 73     78    Grupo de Investigación del SENA COMM (INVECOMM)
# 74     79  Grupo de Estudios en Recursos Hidrobiológicos ...
#
#                                         Datos básicos  \
# 0   Año y mes de formación:  1991 - 6...  \n Depar...
# 1   Año y mes de formación:  2000 - 11...  \n Depa...
# 2   Año y mes de formación:  1993 - 4...  \n Depar...
# 3   Año y mes de formación:  1985 - 3...  \n Depar...
# 4   Año y mes de formación:  1984 - 1...  \n Depar...
# ..                                                ...
# 70  Año y mes de formación:  2005 - 6...  \n Depar...
# 71  Año y mes de formación:  2007 - 2...  \n Depar...
# 72  Año y mes de formación:  2012 - 1...  \n Depar...
# 73  Año y mes de formación:  2014 - 1...  \n Depar...
# 74  Año y mes de formación:  1980 - 1...  \n Depar...
#
#                                         Instituciones  \
# 0            1.- UNIVERSIDAD DE LOS ANDES - (Avalado)
# 1            1.- UNIVERSIDAD DE ANTIOQUIA - (Avalado)
# 2            1.- UNIVERSIDAD DE ANTIOQUIA - (Avalado)
# 3   1.- INSTITUTO DE INVESTIGACIONES MARINAS Y COS...
# 4    1.- UNIVERSIDAD NACIONAL DE COLOMBIA - (Avalado)
# ..                                                ...
# 70              1.- UNIVERSIDAD DEL CAUCA - (Avalado)
# 71  1.- Centro De Educacion Militar - (Avalado) \n...
# 72  1.- Fundación Universitaria de San Gil - UNISA...
# 73  1.- SERVICIO NACIONAL DE APRENDIZAJE SENA - (A...
# 74  1.- UNIVERSIDAD DEL CAUCA - (Avalado) \n 2.- U...
#
#                                      Plan Estratégico  \
# 0   Plan de trabajo: Estado del arte: Objetivos: C...
# 1   Plan de trabajo: El Grupo Diagnostico y Contro...
# 2   Plan de trabajo: ESTRATEGIAS Investigación: *P...
# 3   Plan de trabajo: Formular y ejecutar proyectos...
# 4   Plan de trabajo: Se Espera impulsar de manera ...
# ..                                                ...
# 70  Plan de trabajo: Parcela Permanente de Monitor...
# 71  Plan de trabajo: El grupo de investigación GIC...
# 72  Plan de trabajo: Para el cumplimiento de las o...
# 73  Plan de trabajo: A Corto plazo: 1. Crear semil...
# 74  Plan de trabajo: El Grupo de Estudios pretende...
#
#       Líneas de investigación declaradas por el grupo  \
# 0   1.- CALIDAD AMBIENTAL \n 2.- CONTROL DE LA CON...
# 1   1.- Contaminacion y Calidad Atmosferica \n 2.-...
# 2   1.- Ecología de ecosistemas acuáticos costeros...
# 3   1.- Ecología marina \n 2.- Evaluación y valora...
# 4   1.- Aguas Subterráneas \n 2.- Calidad del Agua...
# ..                                                ...
# 70  1.- Biología de la Conservación \n 2.- Ecologí...
# 71  1.- Ciberdefensa y Ciberseguridad \n 2.- Siste...
# 72  1.- Algoritmia \n 2.- Auditoria \n 3.- Desarro...
# 73  1.- Bellas Artes \n 2.- Ciencias de la Educaci...
# 74  1.- Calidad física, química y biológica del ag...
#
#                                 Integrantes del grupo  \
# 0   Nombre \n 1.- Ricardo Morales Betancourt \n 2....
# 1   Nombre \n 1.- Gustavo Antonio Peñuela Mesa \n ...
# 2   Nombre \n 1.- Francisco José Molina Pérez \n 2...
# 3   Nombre \n 1.- Mario Enrique Rueda Hernández \n...
# 4   Nombre \n 1.- Andrés Ochoa Jaramillo \n 2.- AD...
# ..                                                ...
# 70  Nombre \n 1.- Luis Germán Gómez Bernal \n 2.- ...
# 71  Nombre \n 1.- Adriana Beatriz González Guerrer...
# 72  Nombre \n 1.- EDISSON RAFAEL CAICEDO ROJAS \n ...
# 73  Nombre \n 1.- Yalhy RESTREPO Restrepo Viana \n...
# 74  Nombre \n 1.- Camilo Ernesto Andrade Sossa \n ...
#
#     PRODUCCIÓN DE FORMACIÓN Y EXTENSIÓN  Programa académico de doctorado  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# ..                                  ...                              ...
# 70                                  NaN                              NaN
# 71                                  NaN                              NaN
# 72                                  NaN                              NaN
# 73                                  NaN                              NaN
# 74                                  NaN                              NaN
#
#     Programa académico de maestría  ...  \
# 0                              NaN  ...
# 1                              NaN  ...
# 2                              NaN  ...
# 3                              NaN  ...
# 4                              NaN  ...
# ..                             ...  ...
# 70                             NaN  ...
# 71                             NaN  ...
# 72                             NaN  ...
# 73                             NaN  ...
# 74                             NaN  ...
#
#     Participación Ciudadana en Proyectos de CTI  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 70                                          NaN
# 71                                          NaN
# 72                                          NaN
# 73                                          NaN
# 74                                          NaN
#
#     Producción en arte, arquitectura y diseño ACTIVIDADES DE FORMACIÓN  \
# 0                                         NaN                      NaN
# 1                                         NaN                      NaN
# 2                                         NaN                      NaN
# 3                                         NaN                      NaN
# 4                                         NaN                      NaN
# ..                                        ...                      ...
# 70                                        NaN                      NaN
# 71                                        NaN                      NaN
# 72                                        NaN                      NaN
# 73                                        NaN                      NaN
# 74                                        NaN                      NaN
#
#     Asesorías al Programa Ondas  Curso de Corta Duración Dictados  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
# ..                          ...                               ...
# 70                          NaN                               NaN
# 71                          NaN                               NaN
# 72                          NaN                               NaN
# 73                          NaN                               NaN
# 74                          NaN                               NaN
#
#                           Trabajos dirigidos/turorías  \
# 0   294.- Trabajos de grado de pregrado : Monitore...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   341.- Trabajo de grado de maestría o especiali...
# ..                                                ...
# 70                                                NaN
# 71  15.- Trabajos de grado de pregrado : Elaboraci...
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
#
#    ACTIVIDADES COMO EVALUADOR  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 70                        NaN
# 71                        NaN
# 72                        NaN
# 73                        NaN
# 74                        NaN
#
#     Jurado/Comisiones evaluadoras de trabajo de grado  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 70  5.- Pregrado : Densidad poblacional y lineamie...
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
#
#    Participación en comités de evaluación Demás trabajos
# 0                                     NaN            NaN
# 1                                     NaN            NaN
# 2                                     NaN            NaN
# 3                                     NaN            NaN
# 4                                     NaN            NaN
# ..                                    ...            ...
# 70                                    NaN            NaN
# 71                                    NaN            NaN
# 72                                    NaN            NaN
# 73                                    NaN            NaN
# 74                                    NaN            NaN
#
# [75 rows x 86 columns]

# %%
palabras_filtro = "agua"
palabras_filtro2 = "monitoreo"


####OJO EL CICLO### 
for i in range (80,83): #tamaño_dfgrupos [0]
    count = i
    try:
        print("Procesando link  ",count," .")
        url = dfgrupos["LINKS"][i]
        r = requests.get(url, verify=False)
        soup = BeautifulSoup(r.text, 'lxml')
        NomGrupo = soup.find("span", class_='celdaEncabezado')
        NombreGrupo = NomGrupo.text
        #Filtrar todas las tablas
        table = soup.find_all('table')
        df = pd.read_html(str(table))
        #Numero de de tablas 
        NumTablas = len(df)
        #CICLO 
        dfcon1 = pd.DataFrame()
        dfcon1["Index"] = [i]
        dfcon1["Nombre del Grupo"] = [NombreGrupo]
        #Tabla numero 0, datos basicos, que es diferente 
        #Tabla de datos 
        df = pd.read_html(str(table))[0]
        #Imputacion de los NAN
        df= df.fillna('Sin dato')
        #Tabla 1 
        tamaño = df.shape
        Nombre = df[0][0]
        Dato = []
        for j in range(1,tamaño[0]):
            Dato.append(df[0][j]+":  "+df[1][j]+"... ")
        Datos = " \n ".join(Dato)
        Datos
        dfcon1[Nombre]= [Datos]
        # Siguientes Tablas 1-5
        print("Procesando link  ",count," ..")
        for i in range (1,6):
            df = pd.read_html(str(table))[i]
            tamaño = df.shape
            Nombre = df[0][0]
            Datos = []
            for j in range(1,tamaño[0]):
                Datos.append(df[0][j])
            Datos = " \n ".join(Datos)
            dfcon1[Nombre]= [Datos] 
        print("Procesando link  ",count," ...")
        # Siguientes Tablas 6-12
        for i in range (6,13):
            df = pd.read_html(str(table))[i]
            tamaño = df.shape
            Nombre = df[0][0]
            df_filtrado = df[df[0].str.contains(palabras_filtro,case=False) & df[0].str.contains(palabras_filtro2,case=False) ] 
            Datos = []
            for j in range(0,tamaño[0]):
                try:
                    Datos.append(df_filtrado[0][j])
                except:
                    pass
            Datos = " \n ".join(Datos) 
            dfcon1[Nombre]= [Datos]
        print("Procesando link  ",count," ....")
        #Tabla 13 -44
        for i in range (13,45):
            df = pd.read_html(str(table))[i]
            tamaño = df.shape
            Nombre = df[0][0]
            Datos = []
            for j in range(1,tamaño[0]):
                try:
                    df_filtrado = df[df[1].str.contains(palabras_filtro,case=False) & df[1].str.contains(palabras_filtro2,case=False) ]               
                    Datos.append(df_filtrado[1][j])
                except:
                    pass
            Datos = " \n ".join(Datos)
            dfcon1[Nombre]= [Datos]
        print("Procesando link  ",count," .....")
        #Table 45 - 46
        for i in range (45,47):
            df = pd.read_html(str(table))[i]
            tamaño = df.shape
            Nombre = df[0][0]
            Datos = []
            for j in range(1,tamaño[0]-1):
                df_filtrado = df[df[1].str.contains(palabras_filtro,case=False) & df[1].str.contains(palabras_filtro2,case=False) ]
                Datos.append(df[1][j])
            Datos = " \n ".join(Datos)
            dfcon1[Nombre]= [Datos]
        print("Procesando link  ",count," ......")
        #Tabla 47 - 84 
        for i in range (47,84):
            df = pd.read_html(str(table))[i]
            tamaño = df.shape
            Nombre = df[0][0]
            Datos = []
            for j in range(1,tamaño[0]-1):
                try:
                    df_filtrado = df[df[1].str.contains(palabras_filtro,case=False) & df[1].str.contains(palabras_filtro2,case=False)] #Case = false para que no importen mayusculas
                    Datos.append(df_filtrado[1][j])
                except:
                    pass
            Datos = " \n ".join(Datos)
            dfcon1[Nombre]= [Datos] 
        dfcon = pd.concat([dfcon, dfcon1])
    except:
            print ("error en link  ",count)
dfcon = dfcon.set_index("Index")
dfcon
# Out:
# Procesando link   80  .
# Procesando link   80  ..
# Procesando link   80  ...
# Procesando link   80  ....
# Procesando link   80  .....
# Procesando link   80  ......
# Procesando link   81  .
# Procesando link   81  ..
# Procesando link   81  ...
# Procesando link   81  ....
# Procesando link   81  .....
# Procesando link   81  ......
# Procesando link   82  .
# error en link   82
#                                         Nombre del Grupo  \
# Index
# 0      CENTRO DE INVESTIGACIONES EN INGENIERIA AMBIENTAL
# 1              Diagnóstico y Control de la Contaminación
# 2      Grupo de Investigación en Gestión y Modelación...
# 3                            INVEMAR - Ecología Pesquera
# 4      Posgrado en Aprovechamiento de Recursos Hidráu...
# ...                                                  ...
# 77     INVESTIGACION UNIVERSITARIA EN TECNOLOGIAS DE ...
# 78       Grupo de Investigación del SENA COMM (INVECOMM)
# 79     Grupo de Estudios en Recursos Hidrobiológicos ...
# 80     Grupo de Investigación en Valoración y Aprovec...
# 81     Unidad de Saneamiento y Biotecnología Ambienta...
#
#                                            Datos básicos  \
# Index
# 0      Año y mes de formación:  1991 - 6...  \n Depar...
# 1      Año y mes de formación:  2000 - 11...  \n Depa...
# 2      Año y mes de formación:  1993 - 4...  \n Depar...
# 3      Año y mes de formación:  1985 - 3...  \n Depar...
# 4      Año y mes de formación:  1984 - 1...  \n Depar...
# ...                                                  ...
# 77     Año y mes de formación:  2012 - 1...  \n Depar...
# 78     Año y mes de formación:  2014 - 1...  \n Depar...
# 79     Año y mes de formación:  1980 - 1...  \n Depar...
# 80     Año y mes de formación:  2000 - 1...  \n Depar...
# 81     Año y mes de formación:  1988 - 2...  \n Depar...
#
#                                            Instituciones  \
# Index
# 0               1.- UNIVERSIDAD DE LOS ANDES - (Avalado)
# 1               1.- UNIVERSIDAD DE ANTIOQUIA - (Avalado)
# 2               1.- UNIVERSIDAD DE ANTIOQUIA - (Avalado)
# 3      1.- INSTITUTO DE INVESTIGACIONES MARINAS Y COS...
# 4       1.- UNIVERSIDAD NACIONAL DE COLOMBIA - (Avalado)
# ...                                                  ...
# 77     1.- Fundación Universitaria de San Gil - UNISA...
# 78     1.- SERVICIO NACIONAL DE APRENDIZAJE SENA - (A...
# 79     1.- UNIVERSIDAD DEL CAUCA - (Avalado) \n 2.- U...
# 80     1.- UNIVERSIDAD TECNOLOGICA DEL CHOCO DIEGO LU...
# 81      1.- PONTIFICIA UNIVERSIDAD JAVERIANA - (Avalado)
#
#                                         Plan Estratégico  \
# Index
# 0      Plan de trabajo: Estado del arte: Objetivos: C...
# 1      Plan de trabajo: El Grupo Diagnostico y Contro...
# 2      Plan de trabajo: ESTRATEGIAS Investigación: *P...
# 3      Plan de trabajo: Formular y ejecutar proyectos...
# 4      Plan de trabajo: Se Espera impulsar de manera ...
# ...                                                  ...
# 77     Plan de trabajo: Para el cumplimiento de las o...
# 78     Plan de trabajo: A Corto plazo: 1. Crear semil...
# 79     Plan de trabajo: El Grupo de Estudios pretende...
# 80     Plan de trabajo: Actividades: Estandarización ...
# 81     Plan de trabajo: El plan de trabajo de USBA es...
#
#          Líneas de investigación declaradas por el grupo  \
# Index
# 0      1.- CALIDAD AMBIENTAL \n 2.- CONTROL DE LA CON...
# 1      1.- Contaminacion y Calidad Atmosferica \n 2.-...
# 2      1.- Ecología de ecosistemas acuáticos costeros...
# 3      1.- Ecología marina \n 2.- Evaluación y valora...
# 4      1.- Aguas Subterráneas \n 2.- Calidad del Agua...
# ...                                                  ...
# 77     1.- Algoritmia \n 2.- Auditoria \n 3.- Desarro...
# 78     1.- Bellas Artes \n 2.- Ciencias de la Educaci...
# 79     1.- Calidad física, química y biológica del ag...
# 80     1.- Aprovechamiento de Residuos Solidos \n 2.-...
# 81     1.- Biodegradacion y biorremediación de ambien...
#
#                                    Integrantes del grupo  \
# Index
# 0      Nombre \n 1.- Ricardo Morales Betancourt \n 2....
# 1      Nombre \n 1.- Gustavo Antonio Peñuela Mesa \n ...
# 2      Nombre \n 1.- Francisco José Molina Pérez \n 2...
# 3      Nombre \n 1.- Mario Enrique Rueda Hernández \n...
# 4      Nombre \n 1.- Andrés Ochoa Jaramillo \n 2.- AD...
# ...                                                  ...
# 77     Nombre \n 1.- EDISSON RAFAEL CAICEDO ROJAS \n ...
# 78     Nombre \n 1.- Yalhy RESTREPO Restrepo Viana \n...
# 79     Nombre \n 1.- Camilo Ernesto Andrade Sossa \n ...
# 80     Nombre \n 1.- Leidy Indira Hinestroza Cordoba ...
# 81     Nombre \n 1.- Gina Pilar López Ramírez \n 2.- ...
#
#       PRODUCCIÓN DE FORMACIÓN Y EXTENSIÓN Programa académico de doctorado  \
# Index
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 77                                    NaN                             NaN
# 78                                    NaN                             NaN
# 79                                    NaN                             NaN
# 80
# 81
#
#       Programa académico de maestría Otro programa académico  ...  \
# Index                                                         ...
# 0                                NaN                     NaN  ...
# 1                                NaN                     NaN  ...
# 2                                NaN                     NaN  ...
# 3                                NaN                     NaN  ...
# 4                                NaN                     NaN  ...
# ...                              ...                     ...  ...
# 77                               NaN                     NaN  ...
# 78                               NaN                     NaN  ...
# 79                               NaN                     NaN  ...
# 80                                                            ...
# 81                                                            ...
#
#       Participación Ciudadana en Proyectos de CTI  \
# Index
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 77                                            NaN
# 78                                            NaN
# 79                                            NaN
# 80
# 81
#
#       Producción en arte, arquitectura y diseño ACTIVIDADES DE FORMACIÓN  \
# Index
# 0                                           NaN                      NaN
# 1                                           NaN                      NaN
# 2                                           NaN                      NaN
# 3                                           NaN                      NaN
# 4                                           NaN                      NaN
# ...                                         ...                      ...
# 77                                          NaN                      NaN
# 78                                          NaN                      NaN
# 79                                          NaN                      NaN
# 80
# 81
#
#       Asesorías al Programa Ondas Curso de Corta Duración Dictados  \
# Index
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# ...                           ...                              ...
# 77                            NaN                              NaN
# 78                            NaN                              NaN
# 79                            NaN                              NaN
# 80
# 81
#
#                              Trabajos dirigidos/turorías  \
# Index
# 0      294.- Trabajos de grado de pregrado : Monitore...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      341.- Trabajo de grado de maestría o especiali...
# ...                                                  ...
# 77                                                   NaN
# 78                                                   NaN
# 79                                                   NaN
# 80
# 81
#
#       ACTIVIDADES COMO EVALUADOR  \
# Index
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 77                           NaN
# 78                           NaN
# 79                           NaN
# 80
# 81
#
#        Jurado/Comisiones evaluadoras de trabajo de grado  \
# Index
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 77                                                   NaN
# 78                                                   NaN
# 79                                                   NaN
# 80
# 81     19.- Pregrado : Evaluación y monitoreo microbi...
#
#                   Participación en comités de evaluación Demás trabajos
# Index
# 0                                                    NaN            NaN
# 1                                                    NaN            NaN
# 2                                                    NaN            NaN
# 3                                                    NaN            NaN
# 4                                                    NaN            NaN
# ...                                                  ...            ...
# 77                                                   NaN            NaN
# 78                                                   NaN            NaN
# 79                                                   NaN            NaN
# 80     5.- Profesor titular : Implementación del Plan...
# 81
#
# [77 rows x 85 columns]

# %%
dfcon.to_excel("InormacionFiltrada.xlsx")

# %%
df = pd.read_excel("InormacionFiltrada.xlsx",engine='openpyxl') #sheet_name='Sheet1', 
df = df.set_index("Index")

# %%
df
# Out:
#                                         Nombre del Grupo  \
# Index
# 0      CENTRO DE INVESTIGACIONES EN INGENIERIA AMBIENTAL
# 1              Diagnóstico y Control de la Contaminación
# 2      Grupo de Investigación en Gestión y Modelación...
# 3                            INVEMAR - Ecología Pesquera
# 4      Posgrado en Aprovechamiento de Recursos Hidráu...
# ...                                                  ...
# 77     INVESTIGACION UNIVERSITARIA EN TECNOLOGIAS DE ...
# 78       Grupo de Investigación del SENA COMM (INVECOMM)
# 79     Grupo de Estudios en Recursos Hidrobiológicos ...
# 80     Grupo de Investigación en Valoración y Aprovec...
# 81     Unidad de Saneamiento y Biotecnología Ambienta...
#
#                                            Datos básicos  \
# Index
# 0      Año y mes de formación:  1991 - 6...  \n Depar...
# 1      Año y mes de formación:  2000 - 11...  \n Depa...
# 2      Año y mes de formación:  1993 - 4...  \n Depar...
# 3      Año y mes de formación:  1985 - 3...  \n Depar...
# 4      Año y mes de formación:  1984 - 1...  \n Depar...
# ...                                                  ...
# 77     Año y mes de formación:  2012 - 1...  \n Depar...
# 78     Año y mes de formación:  2014 - 1...  \n Depar...
# 79     Año y mes de formación:  1980 - 1...  \n Depar...
# 80     Año y mes de formación:  2000 - 1...  \n Depar...
# 81     Año y mes de formación:  1988 - 2...  \n Depar...
#
#                                            Instituciones  \
# Index
# 0               1.- UNIVERSIDAD DE LOS ANDES - (Avalado)
# 1               1.- UNIVERSIDAD DE ANTIOQUIA - (Avalado)
# 2               1.- UNIVERSIDAD DE ANTIOQUIA - (Avalado)
# 3      1.- INSTITUTO DE INVESTIGACIONES MARINAS Y COS...
# 4       1.- UNIVERSIDAD NACIONAL DE COLOMBIA - (Avalado)
# ...                                                  ...
# 77     1.- Fundación Universitaria de San Gil - UNISA...
# 78     1.- SERVICIO NACIONAL DE APRENDIZAJE SENA - (A...
# 79     1.- UNIVERSIDAD DEL CAUCA - (Avalado) \n 2.- U...
# 80     1.- UNIVERSIDAD TECNOLOGICA DEL CHOCO DIEGO LU...
# 81      1.- PONTIFICIA UNIVERSIDAD JAVERIANA - (Avalado)
#
#                                         Plan Estratégico  \
# Index
# 0      Plan de trabajo: Estado del arte: Objetivos: C...
# 1      Plan de trabajo: El Grupo Diagnostico y Contro...
# 2      Plan de trabajo: ESTRATEGIAS Investigación: *P...
# 3      Plan de trabajo: Formular y ejecutar proyectos...
# 4      Plan de trabajo: Se Espera impulsar de manera ...
# ...                                                  ...
# 77     Plan de trabajo: Para el cumplimiento de las o...
# 78     Plan de trabajo: A Corto plazo: 1. Crear semil...
# 79     Plan de trabajo: El Grupo de Estudios pretende...
# 80     Plan de trabajo: Actividades: Estandarización ...
# 81     Plan de trabajo: El plan de trabajo de USBA es...
#
#          Líneas de investigación declaradas por el grupo  \
# Index
# 0      1.- CALIDAD AMBIENTAL \n 2.- CONTROL DE LA CON...
# 1      1.- Contaminacion y Calidad Atmosferica \n 2.-...
# 2      1.- Ecología de ecosistemas acuáticos costeros...
# 3      1.- Ecología marina \n 2.- Evaluación y valora...
# 4      1.- Aguas Subterráneas \n 2.- Calidad del Agua...
# ...                                                  ...
# 77     1.- Algoritmia \n 2.- Auditoria \n 3.- Desarro...
# 78     1.- Bellas Artes \n 2.- Ciencias de la Educaci...
# 79     1.- Calidad física, química y biológica del ag...
# 80     1.- Aprovechamiento de Residuos Solidos \n 2.-...
# 81     1.- Biodegradacion y biorremediación de ambien...
#
#                                    Integrantes del grupo  \
# Index
# 0      Nombre \n 1.- Ricardo Morales Betancourt \n 2....
# 1      Nombre \n 1.- Gustavo Antonio Peñuela Mesa \n ...
# 2      Nombre \n 1.- Francisco José Molina Pérez \n 2...
# 3      Nombre \n 1.- Mario Enrique Rueda Hernández \n...
# 4      Nombre \n 1.- Andrés Ochoa Jaramillo \n 2.- AD...
# ...                                                  ...
# 77     Nombre \n 1.- EDISSON RAFAEL CAICEDO ROJAS \n ...
# 78     Nombre \n 1.- Yalhy RESTREPO Restrepo Viana \n...
# 79     Nombre \n 1.- Camilo Ernesto Andrade Sossa \n ...
# 80     Nombre \n 1.- Leidy Indira Hinestroza Cordoba ...
# 81     Nombre \n 1.- Gina Pilar López Ramírez \n 2.- ...
#
#        PRODUCCIÓN DE FORMACIÓN Y EXTENSIÓN  Programa académico de doctorado  \
# Index
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
# ...                                    ...                              ...
# 77                                     NaN                              NaN
# 78                                     NaN                              NaN
# 79                                     NaN                              NaN
# 80                                     NaN                              NaN
# 81                                     NaN                              NaN
#
#        Programa académico de maestría  Otro programa académico  ...  \
# Index                                                           ...
# 0                                 NaN                      NaN  ...
# 1                                 NaN                      NaN  ...
# 2                                 NaN                      NaN  ...
# 3                                 NaN                      NaN  ...
# 4                                 NaN                      NaN  ...
# ...                               ...                      ...  ...
# 77                                NaN                      NaN  ...
# 78                                NaN                      NaN  ...
# 79                                NaN                      NaN  ...
# 80                                NaN                      NaN  ...
# 81                                NaN                      NaN  ...
#
#        Participación Ciudadana en Proyectos de CTI  \
# Index
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 77                                             NaN
# 78                                             NaN
# 79                                             NaN
# 80                                             NaN
# 81                                             NaN
#
#       Producción en arte, arquitectura y diseño  ACTIVIDADES DE FORMACIÓN  \
# Index
# 0                                           NaN                       NaN
# 1                                           NaN                       NaN
# 2                                           NaN                       NaN
# 3                                           NaN                       NaN
# 4                                           NaN                       NaN
# ...                                         ...                       ...
# 77                                          NaN                       NaN
# 78                                          NaN                       NaN
# 79                                          NaN                       NaN
# 80                                          NaN                       NaN
# 81                                          NaN                       NaN
#
#        Asesorías al Programa Ondas Curso de Corta Duración Dictados  \
# Index
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
# ...                            ...                              ...
# 77                             NaN                              NaN
# 78                             NaN                              NaN
# 79                             NaN                              NaN
# 80                             NaN                              NaN
# 81                             NaN                              NaN
#
#                              Trabajos dirigidos/turorías  \
# Index
# 0      294.- Trabajos de grado de pregrado : Monitore...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      341.- Trabajo de grado de maestría o especiali...
# ...                                                  ...
# 77                                                   NaN
# 78                                                   NaN
# 79                                                   NaN
# 80                                                   NaN
# 81                                                   NaN
#
#        ACTIVIDADES COMO EVALUADOR  \
# Index
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 77                            NaN
# 78                            NaN
# 79                            NaN
# 80                            NaN
# 81                            NaN
#
#        Jurado/Comisiones evaluadoras de trabajo de grado  \
# Index
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 77                                                   NaN
# 78                                                   NaN
# 79                                                   NaN
# 80                                                   NaN
# 81     19.- Pregrado : Evaluación y monitoreo microbi...
#
#                   Participación en comités de evaluación Demás trabajos
# Index
# 0                                                    NaN            NaN
# 1                                                    NaN            NaN
# 2                                                    NaN            NaN
# 3                                                    NaN            NaN
# 4                                                    NaN            NaN
# ...                                                  ...            ...
# 77                                                   NaN            NaN
# 78                                                   NaN            NaN
# 79                                                   NaN            NaN
# 80     5.- Profesor titular : Implementación del Plan...            NaN
# 81                                                   NaN            NaN
#
# [77 rows x 85 columns]

# %%
#leer el DataFrame e imprimir cada columna como una tabla nueva

# %%
##Eliminar los sin dato y los vacios (:  -)

#Crear tabla de datos basicos
DatosBasicos = pd.DataFrame(columns=['Nombre del Grupo','Datos básicos'])
for j in range(0,df.shape[0]):
    try:
        dfDatosBasidos = pd.DataFrame(columns=['Nombre del Grupo','Datos básicos'])
        ListaDatosBasicos = df["Datos básicos"][j].split("... ")
        for i in range (0,len(ListaDatosBasicos)-1):
            if i == 0:
                dfDatosBasidos.loc[len(dfDatosBasidos)] = [df["Nombre del Grupo"][j], ListaDatosBasicos[i]]
            else:
                dfDatosBasidos.loc[len(dfDatosBasidos)] = ["", ListaDatosBasicos[i]]
        #REMOVER LAS FILAS QUE NO SIRVEN 
        v1 = dfDatosBasidos.iloc[:, 1].str.contains("sin dato",case=False)
        v2 = dfDatosBasidos.iloc[:, 1].str.contains(":  -",case=False)
        for i in range (0,len(ListaDatosBasicos)-1):
            if (v1[i] == True) or (v2[i] == True):
                dfDatosBasidos = dfDatosBasidos.drop([i],axis=0)
        DatosBasicos = pd.concat([DatosBasicos, dfDatosBasidos])
    except: 
        pass
DatosBasicos.to_excel("DatosBasicos.xlsx")
DatosBasicos
# Out:
#                                      Nombre del Grupo  \
# 0   CENTRO DE INVESTIGACIONES EN INGENIERIA AMBIENTAL
# 1
# 2
# 3
# 4
# ..                                                ...
# 5
# 6
# 7
# 8
# 9
#
#                                         Datos básicos
# 0                   Año y mes de formación:  1991 - 6
# 1    \n Departamento - Ciudad:  BOGOTÁ, D. C. - BO...
# 2               \n Líder:  Ricardo Morales Betancourt
# 3    \n ¿La información de este grupo se ha certif...
# 4         \n Página web:  http://ciia.uniandes.edu.co
# ..                                                ...
# 5    \n E-mail:  cienciatecnologia.escom@cedoc.edu.co
# 6    \n Clasificación:  C  con vigencia hasta la p...
# 7    \n Área de conocimiento:  Ingeniería y Tecnol...
# 8    \n Programa nacional de ciencia y tecnología:...
# 9    \n Programa nacional de ciencia y tecnología ...
#
# [680 rows x 2 columns]

# %%
# Crear tabla de informacion de los grupos 
DatosGrupo = df.iloc[:,0:6].drop(["Datos básicos"],axis=1)
DatosGrupo.to_excel("DatosGrupo.xlsx")
DatosGrupo
# Out:
#                                         Nombre del Grupo  \
# Index
# 0      CENTRO DE INVESTIGACIONES EN INGENIERIA AMBIENTAL
# 1              Diagnóstico y Control de la Contaminación
# 2      Grupo de Investigación en Gestión y Modelación...
# 3                            INVEMAR - Ecología Pesquera
# 4      Posgrado en Aprovechamiento de Recursos Hidráu...
# ...                                                  ...
# 77     INVESTIGACION UNIVERSITARIA EN TECNOLOGIAS DE ...
# 78       Grupo de Investigación del SENA COMM (INVECOMM)
# 79     Grupo de Estudios en Recursos Hidrobiológicos ...
# 80     Grupo de Investigación en Valoración y Aprovec...
# 81     Unidad de Saneamiento y Biotecnología Ambienta...
#
#                                            Instituciones  \
# Index
# 0               1.- UNIVERSIDAD DE LOS ANDES - (Avalado)
# 1               1.- UNIVERSIDAD DE ANTIOQUIA - (Avalado)
# 2               1.- UNIVERSIDAD DE ANTIOQUIA - (Avalado)
# 3      1.- INSTITUTO DE INVESTIGACIONES MARINAS Y COS...
# 4       1.- UNIVERSIDAD NACIONAL DE COLOMBIA - (Avalado)
# ...                                                  ...
# 77     1.- Fundación Universitaria de San Gil - UNISA...
# 78     1.- SERVICIO NACIONAL DE APRENDIZAJE SENA - (A...
# 79     1.- UNIVERSIDAD DEL CAUCA - (Avalado) \n 2.- U...
# 80     1.- UNIVERSIDAD TECNOLOGICA DEL CHOCO DIEGO LU...
# 81      1.- PONTIFICIA UNIVERSIDAD JAVERIANA - (Avalado)
#
#                                         Plan Estratégico  \
# Index
# 0      Plan de trabajo: Estado del arte: Objetivos: C...
# 1      Plan de trabajo: El Grupo Diagnostico y Contro...
# 2      Plan de trabajo: ESTRATEGIAS Investigación: *P...
# 3      Plan de trabajo: Formular y ejecutar proyectos...
# 4      Plan de trabajo: Se Espera impulsar de manera ...
# ...                                                  ...
# 77     Plan de trabajo: Para el cumplimiento de las o...
# 78     Plan de trabajo: A Corto plazo: 1. Crear semil...
# 79     Plan de trabajo: El Grupo de Estudios pretende...
# 80     Plan de trabajo: Actividades: Estandarización ...
# 81     Plan de trabajo: El plan de trabajo de USBA es...
#
#          Líneas de investigación declaradas por el grupo  \
# Index
# 0      1.- CALIDAD AMBIENTAL \n 2.- CONTROL DE LA CON...
# 1      1.- Contaminacion y Calidad Atmosferica \n 2.-...
# 2      1.- Ecología de ecosistemas acuáticos costeros...
# 3      1.- Ecología marina \n 2.- Evaluación y valora...
# 4      1.- Aguas Subterráneas \n 2.- Calidad del Agua...
# ...                                                  ...
# 77     1.- Algoritmia \n 2.- Auditoria \n 3.- Desarro...
# 78     1.- Bellas Artes \n 2.- Ciencias de la Educaci...
# 79     1.- Calidad física, química y biológica del ag...
# 80     1.- Aprovechamiento de Residuos Solidos \n 2.-...
# 81     1.- Biodegradacion y biorremediación de ambien...
#
#                                    Integrantes del grupo
# Index
# 0      Nombre \n 1.- Ricardo Morales Betancourt \n 2....
# 1      Nombre \n 1.- Gustavo Antonio Peñuela Mesa \n ...
# 2      Nombre \n 1.- Francisco José Molina Pérez \n 2...
# 3      Nombre \n 1.- Mario Enrique Rueda Hernández \n...
# 4      Nombre \n 1.- Andrés Ochoa Jaramillo \n 2.- AD...
# ...                                                  ...
# 77     Nombre \n 1.- EDISSON RAFAEL CAICEDO ROJAS \n ...
# 78     Nombre \n 1.- Yalhy RESTREPO Restrepo Viana \n...
# 79     Nombre \n 1.- Camilo Ernesto Andrade Sossa \n ...
# 80     Nombre \n 1.- Leidy Indira Hinestroza Cordoba ...
# 81     Nombre \n 1.- Gina Pilar López Ramírez \n 2.- ...
#
# [77 rows x 5 columns]

# %%
# Crear todas las tablas en archivos diferentes. 

df1 = df.set_index("Nombre del Grupo")
for i in range(5,84):
    try:
        NombreColumna = df1.columns[i]
        Nombre = str(i)+' '+NombreColumna+".xlsx"
        dfsin_nan = df1[NombreColumna].dropna()
        try:
            if type(dfsin_nan[0]) != str():
                dfsin_nan.to_excel(Nombre)
        except:
            pass
    except:
        pass
